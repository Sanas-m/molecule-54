# %% [markdown]
# # Untransfected_AngII_Analysis

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from numpy import float64, subtract, divide
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
def convert_rep(row):
    row['rep'] = row['Sample Name'][-1]
    row['Sample Name'] = row['Sample Name'][:len(row['Sample Name']) - 5]
    return row

# %%
rawDataSet_2 = pd.read_excel(r'/Users/sanas/Projects/molecule-54/AngII-stim/resources/AngII_rep2.xlsx', sheet_name = 'Results', header = 50, decimal = ",")
rawDataSet_3and4 = pd.read_excel(r'/Users/sanas/Projects/molecule-54/AngII-stim/resources/AngII_rep3-rep4.xls', sheet_name = 'Results', header = 50, decimal = ",")
rawDataSet_5and6 = pd.read_excel(r'/Users/sanas/Projects/molecule-54/AngII-stim/resources/AngII_rep5-rep6.xls', sheet_name = 'Results', header = 50, decimal = ",")


AngII_clean_2 = rawDataSet_2.drop(columns = ['Well', 'Well Position', 'Omit', 'Task', 'Reporter', 'Quencher', 'Quantity', \
                                    'Quantity Mean', 'Quantity SD', 'RQ', 'RQ Min', 'RQ Max', 'Delta Ct', 'Delta Ct Mean', \
                                     'Delta Ct SD', 'Delta Ct SE', 'Delta Delta Ct', 'Automatic Ct Threshold', \
                                     'Ct Threshold', 'Automatic Baseline', 'Baseline Start', \
                                    'Baseline End', 'Amp Status', 'Comments', 'Cq Conf', 'CQCONF', 'EXPFAIL', 'NOAMP', 'HIGHSD'])

AngII_clean_2['rep'] = '2'
AngII_clean_2 = AngII_clean_2[AngII_clean_2['Sample Name'].str.contains('rep')== False ]
AngII_wo_na_2 = AngII_clean_2.dropna(axis = 0)
AngII_wo_na_2
# Out:
#        Sample Name Target Name         CT    Ct Mean     Ct SD rep
# 36   Untransfected       GAPDH  28.776197  28.775597  0.000850   2
# 37   Untransfected       GAPDH  28.774996  28.775597  0.000850   2
# 38           AngII       GAPDH  28.257355  28.042526  0.303812   2
# 39           AngII       GAPDH    27.8277  28.042526  0.303812   2
# 40  AngII + mol-54       GAPDH  28.284531  28.189013  0.135083   2
# 41  AngII + mol-54       GAPDH  28.093494  28.189013  0.135083   2
# 42   Untransfected     CYP11B2  34.982246  34.775848  0.291888   2
# 43   Untransfected     CYP11B2  34.569454  34.775848  0.291888   2
# 44           AngII     CYP11B2    27.3069  27.335764  0.040820   2
# 45           AngII     CYP11B2  27.364628  27.335764  0.040820   2
# 46  AngII + mol-54     CYP11B2  28.065977  28.031193  0.049194   2
# 47  AngII + mol-54     CYP11B2  27.996407  28.031193  0.049194   2

# %%
AngII_clean_3and4 = rawDataSet_3and4.drop(columns = ['Well', 'Well Position', 'Omit', 'Task', 'Reporter', 'Quencher', 'Quantity', \
                                    'Quantity Mean', 'Quantity SD', 'RQ', 'RQ Min', 'RQ Max', 'Delta Ct', 'Delta Ct Mean', \
                                     'Delta Ct SD', 'Delta Ct SE', 'Delta Delta Ct', 'Automatic Ct Threshold', \
                                     'Ct Threshold', 'Automatic Baseline', 'Baseline Start', \
                                    'Baseline End', 'Amp Status', 'Comments', 'Cq Conf', 'CQCONF', 'EXPFAIL', 'NOAMP',])

AngII_clean_3and4 = AngII_clean_3and4.dropna(axis = 0)
AngII_clean_3and4 = AngII_clean_3and4[AngII_clean_3and4['Sample Name'].str.contains('rep')]
AngII_clean_3and4 = AngII_clean_3and4.apply(convert_rep, axis = 1)

AngII_clean_3and4
# Out:
#        Sample Name Target Name         CT    Ct Mean     Ct SD rep
# 0        Untreated       GAPDH  26.233788  26.120548  0.160143   3
# 1        Untreated       GAPDH  26.007311  26.120548  0.160143   3
# 2            AngII       GAPDH  25.752451  25.775509  0.032607   3
# 3            AngII       GAPDH  25.798565  25.775509  0.032607   3
# 4   AngII + mol-54       GAPDH  25.821255  25.801086  0.028524   3
# 5   AngII + mol-54       GAPDH  25.780916  25.801086  0.028524   3
# 6        Untreated       GAPDH  25.808231  25.875061  0.094513   4
# 7        Untreated       GAPDH  25.941893  25.875061  0.094513   4
# 8            AngII       GAPDH  26.090498  26.234150  0.203156   4
# 9            AngII       GAPDH  26.377804  26.234150  0.203156   4
# 10  AngII + mol-54       GAPDH  26.282017  26.163921  0.167013   4
# 11  AngII + mol-54       GAPDH  26.045824  26.163921  0.167013   4
# 12       Untreated     CYP11B2  31.099165  31.104525  0.007580   3
# ...

# %%
AngII_clean_5and6 = rawDataSet_5and6.drop(columns = ['Well', 'Well Position', 'Omit', 'Task', 'Reporter', 'Quencher', 'Quantity', \
                                    'Quantity Mean', 'Quantity SD', 'RQ', 'RQ Min', 'RQ Max', 'Delta Ct', 'Delta Ct Mean', \
                                     'Delta Ct SD', 'Delta Ct SE', 'Delta Delta Ct', 'Automatic Ct Threshold', \
                                     'Ct Threshold', 'Automatic Baseline', 'Baseline Start', \
                                    'Baseline End', 'Amp Status', 'Comments', 'Cq Conf', 'CQCONF', 'EXPFAIL']) 

AngII_clean_5and6 = AngII_clean_5and6.dropna(axis = 0)
AngII_clean_5and6 = AngII_clean_5and6[AngII_clean_5and6['Sample Name'].str.contains('rep')]
AngII_clean_5and6 = AngII_clean_5and6.apply(convert_rep, axis = 1)

AngII_clean_5and6
# Out:
#        Sample Name Target Name         CT    Ct Mean     Ct SD rep
# 0        Untreated       GAPDH  26.276197  25.926300  0.494828   5
# 1        Untreated       GAPDH  25.576405  25.926300  0.494828   5
# 2            AngII       GAPDH  24.931860  25.112541  0.255523   5
# 3            AngII       GAPDH  25.293224  25.112541  0.255523   5
# 4     AngII + m-54       GAPDH  24.767658  24.795723  0.039690   5
# 5     AngII + m-54       GAPDH  24.823788  24.795723  0.039690   5
# 6        Untreated       GAPDH  25.230234  25.346279  0.164111   6
# 7        Untreated       GAPDH  25.462322  25.346279  0.164111   6
# 8            AngII       GAPDH  25.285358  25.346550  0.086538   6
# 9            AngII       GAPDH  25.407742  25.346550  0.086538   6
# 10  AngII + mol-54       GAPDH  25.356382  25.558651  0.286052   6
# 11  AngII + mol-54       GAPDH  25.760921  25.558651  0.286052   6
# 12       Untreated     CYP11B2  32.204502  32.341404  0.193608   5
# ...

# %%
mergedAngII = pd.concat([AngII_wo_na_2, AngII_clean_3and4, AngII_clean_5and6]).replace('Untransfected', 'Untreated', regex = True).replace('mol-54', 'm-54', regex = True)
mergedAngII
# Out:
#      Sample Name Target Name         CT    Ct Mean     Ct SD rep
# 36     Untreated       GAPDH  28.776197  28.775597  0.000850   2
# 37     Untreated       GAPDH  28.774996  28.775597  0.000850   2
# 38         AngII       GAPDH  28.257355  28.042526  0.303812   2
# 39         AngII       GAPDH  27.827700  28.042526  0.303812   2
# 40  AngII + m-54       GAPDH  28.284531  28.189013  0.135083   2
# 41  AngII + m-54       GAPDH  28.093494  28.189013  0.135083   2
# 42     Untreated     CYP11B2  34.982246  34.775848  0.291888   2
# 43     Untreated     CYP11B2  34.569454  34.775848  0.291888   2
# 44         AngII     CYP11B2  27.306900  27.335764  0.040820   2
# 45         AngII     CYP11B2  27.364628  27.335764  0.040820   2
# 46  AngII + m-54     CYP11B2  28.065977  28.031193  0.049194   2
# 47  AngII + m-54     CYP11B2  27.996407  28.031193  0.049194   2
# 0      Untreated       GAPDH  26.233788  26.120548  0.160143   3
# ...

# %%
AngII_data_dedupl = mergedAngII.drop(columns=['CT', 'Ct SD']).drop_duplicates()
AngII_data_dedupl
# Out:
#      Sample Name Target Name    Ct Mean rep
# 36     Untreated       GAPDH  28.775597   2
# 38         AngII       GAPDH  28.042526   2
# 40  AngII + m-54       GAPDH  28.189013   2
# 42     Untreated     CYP11B2  34.775848   2
# 44         AngII     CYP11B2  27.335764   2
# 46  AngII + m-54     CYP11B2  28.031193   2
# 0      Untreated       GAPDH  26.120548   3
# 2          AngII       GAPDH  25.775509   3
# 4   AngII + m-54       GAPDH  25.801086   3
# 6      Untreated       GAPDH  25.875061   4
# 8          AngII       GAPDH  26.234150   4
# 10  AngII + m-54       GAPDH  26.163921   4
# 12     Untreated     CYP11B2  31.104525   3
# 14         AngII     CYP11B2  25.130394   3
# 16  AngII + m-54     CYP11B2  25.985344   3
# 17     Untreated     CYP11B2  31.857391   4
# 19         AngII     CYP11B2  25.812138   4
# 21  AngII + m-54     CYP11B2  26.825146   4
# 0      Untreated       GAPDH  25.926300   5
# 2          AngII       GAPDH  25.112541   5
# ...

# %%
CYP11B2_values = AngII_data_dedupl[AngII_data_dedupl['Target Name'] == 'CYP11B2']

def delta_CT(CYP11B2_value):
    GAPDH_value = AngII_data_dedupl[(AngII_data_dedupl['Target Name'] == 'GAPDH') &
                                    (AngII_data_dedupl['Sample Name'] == CYP11B2_value['Sample Name']) &
                                    (AngII_data_dedupl['rep'] == CYP11B2_value['rep'])
                                  ]
    CYP11B2_value['GAPDH'] = float64(GAPDH_value['Ct Mean'])
    CYP11B2_value['Delta CT'] = float64(subtract(CYP11B2_value['Ct Mean'], GAPDH_value['Ct Mean']))   
    
    return CYP11B2_value

deltaCT_CYP11B2 = CYP11B2_values.apply(delta_CT, axis = 1).drop(columns = ['Target Name', 'GAPDH'])
deltaCT_CYP11B2
# Out:
#      Sample Name    Ct Mean rep  Delta CT
# 42     Untreated  34.775848   2  6.000252
# 44         AngII  27.335764   2 -0.706762
# 46  AngII + m-54  28.031193   2 -0.157820
# 12     Untreated  31.104525   3  4.983976
# 14         AngII  25.130394   3 -0.645115
# 16  AngII + m-54  25.985344   3  0.184258
# 17     Untreated  31.857391   4  5.982330
# 19         AngII  25.812138   4 -0.422012
# 21  AngII + m-54  26.825146   4  0.661224
# 12     Untreated  32.341404   5  6.415104
# 14         AngII  25.824665   5  0.712124
# 16  AngII + m-54  26.721720   5  1.925997
# 18     Untreated  31.969683   6  6.623404
# 20         AngII  26.047600   6  0.701050
# 22  AngII + m-54  28.118612   6  2.559961

# %%
doubleDeltaCT_CYP11B2 = 2 ** (-deltaCT_CYP11B2['Delta CT'])
float64(doubleDeltaCT_CYP11B2)
# Out:
# array([0.01562227, 1.63213717, 1.11559993, 0.03159902, 1.56386383,
#        0.88010191, 0.01581755, 1.33979505, 0.63234142, 0.01171821,
#        0.61042084, 0.26315838, 0.01014278, 0.61512444, 0.16958009])

# %%
deltaCT_CYP11B2['Double Delta CT'] = doubleDeltaCT_CYP11B2
deltaCT_CYP11B2
# Out:
#      Sample Name    Ct Mean rep  Delta CT  Double Delta CT
# 42     Untreated  34.775848   2  6.000252         0.015622
# 44         AngII  27.335764   2 -0.706762         1.632137
# 46  AngII + m-54  28.031193   2 -0.157820         1.115600
# 12     Untreated  31.104525   3  4.983976         0.031599
# 14         AngII  25.130394   3 -0.645115         1.563864
# 16  AngII + m-54  25.985344   3  0.184258         0.880102
# 17     Untreated  31.857391   4  5.982330         0.015818
# 19         AngII  25.812138   4 -0.422012         1.339795
# 21  AngII + m-54  26.825146   4  0.661224         0.632341
# 12     Untreated  32.341404   5  6.415104         0.011718
# 14         AngII  25.824665   5  0.712124         0.610421
# 16  AngII + m-54  26.721720   5  1.925997         0.263158
# 18     Untreated  31.969683   6  6.623404         0.010143
# 20         AngII  26.047600   6  0.701050         0.615124
# 22  AngII + m-54  28.118612   6  2.559961         0.169580

# %% [markdown]
# ### Manual division

# %%
def extract_untreated (browsed_dataframe):
    untreated = browsed_dataframe[(browsed_dataframe['Sample Name'] == 'Untreated') &
                          (browsed_dataframe['rep'] == browsed_dataframe['rep'])
                         ]
    return untreated

untreated_per_rep = extract_untreated(deltaCT_CYP11B2).set_index('rep')
untreated_per_rep
# Out:
#     Sample Name    Ct Mean  Delta CT  Double Delta CT
# rep
# 2     Untreated  34.775848  6.000252         0.015622
# 3     Untreated  31.104525  4.983976         0.031599
# 4     Untreated  31.857391  5.982330         0.015818
# 5     Untreated  32.341404  6.415104         0.011718
# 6     Untreated  31.969683  6.623404         0.010143

# %%
def extract_angII (browsed_dataframe):
    angII = browsed_dataframe[(browsed_dataframe['Sample Name'] == 'AngII') &
                          (browsed_dataframe['rep'] == browsed_dataframe['rep'])
                         ]
    return angII

angII_per_rep = extract_angII(deltaCT_CYP11B2).set_index('rep')
angII_per_rep
# Out:
#     Sample Name    Ct Mean  Delta CT  Double Delta CT
# rep
# 2         AngII  27.335764 -0.706762         1.632137
# 3         AngII  25.130394 -0.645115         1.563864
# 4         AngII  25.812138 -0.422012         1.339795
# 5         AngII  25.824665  0.712124         0.610421
# 6         AngII  26.047600  0.701050         0.615124

# %%
def extract_angII_m54 (browsed_dataframe):
    angII_m54 = browsed_dataframe[(browsed_dataframe['Sample Name'] == 'AngII + m-54') &
                          (browsed_dataframe['rep'] == browsed_dataframe['rep'])
                         ]
    return angII_m54

angII_m54_per_rep = extract_angII_m54(deltaCT_CYP11B2).set_index('rep')
angII_m54_per_rep
# Out:
#       Sample Name    Ct Mean  Delta CT  Double Delta CT
# rep
# 2    AngII + m-54  28.031193 -0.157820         1.115600
# 3    AngII + m-54  25.985344  0.184258         0.880102
# 4    AngII + m-54  26.825146  0.661224         0.632341
# 5    AngII + m-54  26.721720  1.925997         0.263158
# 6    AngII + m-54  28.118612  2.559961         0.169580

# %%
angII_per_rep['Untreated double delta'] = untreated_per_rep['Double Delta CT']
angII_per_rep
# Out:
#     Sample Name    Ct Mean  Delta CT  Double Delta CT  Untreated double delta
# rep
# 2         AngII  27.335764 -0.706762         1.632137                0.015622
# 3         AngII  25.130394 -0.645115         1.563864                0.031599
# 4         AngII  25.812138 -0.422012         1.339795                0.015818
# 5         AngII  25.824665  0.712124         0.610421                0.011718
# 6         AngII  26.047600  0.701050         0.615124                0.010143

# %%
angII_per_rep['result'] = angII_per_rep['Double Delta CT'].div(angII_per_rep['Untreated double delta'].values,axis=0)
angII_per_rep
# Out:
#     Sample Name    Ct Mean  Delta CT  Double Delta CT  Untreated double delta  \
# rep
# 2         AngII  27.335764 -0.706762         1.632137                0.015622
# 3         AngII  25.130394 -0.645115         1.563864                0.031599
# 4         AngII  25.812138 -0.422012         1.339795                0.015818
# 5         AngII  25.824665  0.712124         0.610421                0.011718
# 6         AngII  26.047600  0.701050         0.615124                0.010143
#
#          result
# rep
# 2    104.475010
# 3     49.490896
# 4     84.703087
# 5     52.091643
# 6     60.646553

# %%
untreated_rep2 = deltaCT_CYP11B2[deltaCT_CYP11B2['rep'] == '2']

untreated_rep3 = deltaCT_CYP11B2[deltaCT_CYP11B2['rep'] == '3']

untreated_rep4 = deltaCT_CYP11B2[deltaCT_CYP11B2['rep'] == '4']

untreated_rep5 = deltaCT_CYP11B2[deltaCT_CYP11B2['rep'] == '5']

untreated_rep6 = deltaCT_CYP11B2[deltaCT_CYP11B2['rep'] == '6']

def foldChange(rep_data_frame):
    untreated = rep_data_frame[rep_data_frame['Sample Name'] == 'Untreated']['Double Delta CT']
    angII = rep_data_frame[rep_data_frame['Sample Name'] == 'AngII']['Double Delta CT']
    angII_m54 = rep_data_frame[rep_data_frame['Sample Name'] == 'AngII + m-54']['Double Delta CT']

    foldChange_angII = divide(float64(angII), float64(untreated))
    foldChange_angIIm54 = divide(float64(angII_m54), float64(untreated))
            
    return [1, foldChange_angII, foldChange_angIIm54]
    
untreated_rep2['Fold Change'] = foldChange(untreated_rep2)
untreated_rep3['Fold Change'] = foldChange(untreated_rep3)
untreated_rep4['Fold Change'] = foldChange(untreated_rep4)
untreated_rep5['Fold Change'] = foldChange(untreated_rep5)
untreated_rep6['Fold Change'] = foldChange(untreated_rep6)
combined = pd.concat([untreated_rep2, untreated_rep3, untreated_rep4, untreated_rep5, untreated_rep6])
combined
# Out:
# /var/folders/k3/y65s0sg95bv4_svkn3b9sfs40000gn/T/ipykernel_64651/3014871953.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   untreated_rep2['Fold Change'] = foldChange(untreated_rep2)
# /var/folders/k3/y65s0sg95bv4_svkn3b9sfs40000gn/T/ipykernel_64651/3014871953.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   untreated_rep3['Fold Change'] = foldChange(untreated_rep3)
# /var/folders/k3/y65s0sg95bv4_svkn3b9sfs40000gn/T/ipykernel_64651/3014871953.py:23: SettingWithCopyWarning:
# ...

# %%
mean = combined.groupby(['Sample Name'])['Fold Change'].mean()
plot_mean = mean.to_frame().rename(columns = {"Fold Change": "Mean Fold Change"})
plot_mean
# Out:
#               Mean Fold Change
# Sample Name
# AngII                70.281438
# AngII + m-54         35.683354
# Untreated             1.000000

# %%
std = combined.groupby(['Sample Name'])['Fold Change'].std()
plot_std = std.to_frame().rename(columns = {"Fold Change": "Std Fold Change"})
plot_std
# Out:
#               Std Fold Change
# Sample Name
# AngII               23.628006
# AngII + m-54        21.741579
# Untreated            0.000000

# %%
plot_data = pd.concat([plot_mean, plot_std], axis = 1)
plot_data
# Out:
#               Mean Fold Change  Std Fold Change
# Sample Name
# AngII                70.281438        23.628006
# AngII + m-54         35.683354        21.741579
# Untreated             1.000000         0.000000

# %%
plot_data.plot.bar(stacked = True)
# Out:
# <AxesSubplot:xlabel='Sample Name'>

# %%
plot_data.plot(kind='bar', y = 'Mean Fold Change', legend = True, title = 'AngII', yerr = 'Std Fold Change')
# Out:
# <AxesSubplot:title={'center':'AngII'}, xlabel='Sample Name'>
